# %% [markdown]
# <a href="https://colab.research.google.com/github/sphuang28/tibaml1017-teamproject/blob/main/%E7%89%B9%E5%BE%B5_%E5%85%AC%E5%B0%BA%E5%85%A7%E8%A8%AD%E6%96%BD%E6%95%B8%E9%87%8F_%E5%96%AE%E4%B8%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import geopy.distance
# 載入房屋交易csv檔

dh = pd.read_csv("data/台北市房屋交易_最新版.csv, encoding = "utf-8")
pd.set_option('display.max_columns', 100)

# %%
#================= 公園 =============

# 載入設施csv檔
df = pd.read_csv("data/公園.csv", encoding = "utf-8") 

dis=input("請輸入公園要改變的距離(km):")

dh["park_d"]=str(dis)
dh["park_q"]=""
for i in range(len(dh)):
    times = 0
    origin_lat = str(dh["lat"][i])
    origin_long = str(dh["lng"][i])
    origin = (origin_lat, origin_long)
    for j in range(len(df)):
        destination_lat = str(df["lat"][j])
        destination_long = str(df["lng"][j])
        destination = (destination_lat, destination_long)
        distance=geopy.distance.geodesic(origin, destination).km
        try:
            if distance <= int(dh["park_d"][0]):
                times = times + 1
                
        except:
            print(i,"error")
    dh.at[i,"post_q"] = times

dh.to_csv("台北市房屋交易_最新版.csv", encoding = "utf-8", index=False)

# %%
#================= 博物館 =============
# 載入設施csv檔
df = pd.read_csv("data/博物館.csv", encoding = "utf-8") 

dis=input("請輸入博物館要改變的距離(km):")

dh["mu_d"]=str(dis)
dh["mu_q"]=""
for i in range(len(dh)):
    times = 0
    origin_lat = str(dh["lat"][i])
    origin_long = str(dh["lng"][i])
    origin = (origin_lat, origin_long)
    for j in range(len(df)):
        destination_lat = str(df["lat"][j])
        destination_long = str(df["lng"][j])
        destination = (destination_lat, destination_long)
        distance=geopy.distance.geodesic(origin, destination).km
        try:
            if distance <= int(dh["mu_d"][0]):
                times = times + 1
                
        except:
            print(i,"error")
    dh.at[i,"mu_q"] = times

dh.to_csv("台北市房屋交易_最新版.csv", encoding = "utf-8", index=False)

# %%
#================= 圖書館 =============

# 載入設施csv檔
df = pd.read_csv("data/圖書館數.csv", encoding = "utf-8") 

dis=input("請輸入圖書館要改變的距離(km):")

dh["lib_d"]=str(dis)
dh["lib_q"]=""
for i in range(len(dh)):
    times = 0
    origin_lat = str(dh["lat"][i])
    origin_long = str(dh["lng"][i])
    origin = (origin_lat, origin_long)
    for j in range(len(df)):
        destination_lat = str(df["lat"][j])
        destination_long = str(df["lng"][j])
        destination = (destination_lat, destination_long)
        distance=geopy.distance.geodesic(origin, destination).km
        try:
            if distance <= int(dh["lib_d"][0]):
                times = times + 1
                
        except:
            print(i,"error")
    dh.at[i,"lib_q"] = times

dh.to_csv("台北市房屋交易_最新版.csv", encoding = "utf-8", index=False)

# %%
#================= 捷運出口數 =============

# 載入設施csv檔
df = pd.read_csv("data/捷運出口數.csv", encoding = "utf-8") 

dis=input("請輸入捷運出口要改變的距離(km):")

dh["mrt_d"]=str(dis)
dh["mrt_q"]=""
for i in range(len(dh)):
    times = 0
    origin_lat = str(dh["lat"][i])
    origin_long = str(dh["lng"][i])
    origin = (origin_lat, origin_long)
    for j in range(len(df)):
        destination_lat = str(df["lat"][j])
        destination_long = str(df["lng"][j])
        destination = (destination_lat, destination_long)
        distance=geopy.distance.geodesic(origin, destination).km
        try:
            if distance <= int(dh["mrt_d"][0]):
                times = times + 1
                
        except:
            print(i,"error")
    dh.at[i,"mrt_q"] = times

dh.to_csv("台北市房屋交易_最新版.csv", encoding = "utf-8", index=False)

# %%
#================= 學校 =============

# 載入設施csv檔
df = pd.read_csv("data/學校.csv", encoding = "utf-8") 

dis=input("請輸入學校要改變的距離(km):")

dh["edu_d"]=str(dis)
dh["edu_q"]=""
for i in range(len(dh)):
    times = 0
    origin_lat = str(dh["lat"][i])
    origin_long = str(dh["lng"][i])
    origin = (origin_lat, origin_long)
    for j in range(len(df)):
        destination_lat = str(df["lat"][j])
        destination_long = str(df["lng"][j])
        destination = (destination_lat, destination_long)
        distance=geopy.distance.geodesic(origin, destination).km
        try:
            if distance <= int(dh["edu_d"][0]):
                times = times + 1
                
        except:
            print(i,"error")
    dh.at[i,"edu_q"] = times

dh.to_csv("台北市房屋交易_最新版.csv", encoding = "utf-8", index=False)

# %%
#================= 消防 =============

# 載入設施csv檔
df = pd.read_csv("data/消防.csv", encoding = "utf-8") 

dis=input("請輸入消防要改變的距離(km):")

dh["fire_d"]=str(dis)
dh["fire_q"]=""
for i in range(len(dh)):
    times = 0
    origin_lat = str(dh["lat"][i])
    origin_long = str(dh["lng"][i])
    origin = (origin_lat, origin_long)
    for j in range(len(df)):
        destination_lat = str(df["lat"][j])
        destination_long = str(df["lng"][j])
        destination = (destination_lat, destination_long)
        distance=geopy.distance.geodesic(origin, destination).km
        try:
            if distance <= int(dh["fire_d"][0]):
                times = times + 1
                
        except:
            print(i,"error")
    dh.at[i,"fire_q"] = times

dh.to_csv("台北市房屋交易_最新版.csv", encoding = "utf-8", index=False)

# %%
#================= 禮儀 =============

# 載入設施csv檔
df = pd.read_csv("data/禮儀.csv", encoding = "utf-8") 

dis=input("請輸入禮儀要改變的距離(km):")

dh["dead_d"]=str(dis)
dh["dead_q"]=""
for i in range(len(dh)):
    times = 0
    origin_lat = str(dh["lat"][i])
    origin_long = str(dh["lng"][i])
    origin = (origin_lat, origin_long)
    for j in range(len(df)):
        destination_lat = str(df["lat"][j])
        destination_long = str(df["lng"][j])
        destination = (destination_lat, destination_long)
        distance=geopy.distance.geodesic(origin, destination).km
        try:
            if distance <= int(dh["dead_d"][0]):
                times = times + 1
                
        except:
            print(i,"error")
    dh.at[i,"deade_q"] = times

dh.to_csv("台北市房屋交易_最新版.csv", encoding = "utf-8", index=False)

# %%
#================= 警察 =============

# 載入設施csv檔
df = pd.read_csv("data/警察.csv", encoding = "utf-8") 

dis=input("請輸入警察要改變的距離(km):")

dh["pol_d"]=str(dis)
dh["pol_q"]=""
for i in range(len(dh)):
    times = 0
    origin_lat = str(dh["lat"][i])
    origin_long = str(dh["lng"][i])
    origin = (origin_lat, origin_long)
    for j in range(len(df)):
        destination_lat = str(df["lat"][j])
        destination_long = str(df["lng"][j])
        destination = (destination_lat, destination_long)
        distance=geopy.distance.geodesic(origin, destination).km
        try:
            if distance <= int(dh["pol_d"][0]):
                times = times + 1
                
        except:
            print(i,"error")
    dh.at[i,"pol_q"] = times

dh.to_csv("台北市房屋交易_最新版.csv", encoding = "utf-8", index=False)

# %%
#================= 郵局 =============

# 載入設施csv檔
df = pd.read_csv("data/郵局test.csv", encoding = "utf-8") 

dis=input("請輸入郵局要改變的距離(km):")

dh["post_d"]=str(dis)
dh["post_q"]=""
for i in range(len(dh)):
    times = 0
    origin_lat = str(dh["lat"][i])
    origin_long = str(dh["lng"][i])
    origin = (origin_lat, origin_long)
    for j in range(len(df)):
        destination_lat = str(df["lat"][j])
        destination_long = str(df["lng"][j])
        destination = (destination_lat, destination_long)
        distance=geopy.distance.geodesic(origin, destination).km
        try:
            if distance <= int(dh["post_d"][0]):
                times = times + 1
                
        except:
            print(i,"error")
    dh.at[i,"post_q"] = times

dh.to_csv("台北市房屋交易_最新版.csv", encoding = "utf-8", index=False)

# %%
#================= 醫療 =============

# 載入設施csv檔
df = pd.read_csv("data/醫療.csv", encoding = "utf-8") 

dis=input("請輸入醫療要改變的距離(km):")

dh["hosp_d"]=str(dis)
dh["hosp_q"]=""
for i in range(len(dh)):
    times = 0
    origin_lat = str(dh["lat"][i])
    origin_long = str(dh["lng"][i])
    origin = (origin_lat, origin_long)
    for j in range(len(df)):
        destination_lat = str(df["lat"][j])
        destination_long = str(df["lng"][j])
        destination = (destination_lat, destination_long)
        distance=geopy.distance.geodesic(origin, destination).km
        try:
            if distance <= int(dh["hosp_d"][0]):
                times = times + 1
                
        except:
            print(i,"error")
    dh.at[i,"hosp_q"] = times

dh.to_csv("台北市房屋交易_最新版.csv", encoding = "utf-8", index=False)

# %%
#================= 金融 =============

# 載入設施csv檔
df = pd.read_csv("data/金融.csv", encoding = "utf-8") 

dis=input("請輸入金融要改變的距離(km):")

dh["fin_d"]=str(dis)
dh["fin_q"]=""
for i in range(len(dh)):
    times = 0
    origin_lat = str(dh["lat"][i])
    origin_long = str(dh["lng"][i])
    origin = (origin_lat, origin_long)
    for j in range(len(df)):
        destination_lat = str(df["lat"][j])
        destination_long = str(df["lng"][j])
        destination = (destination_lat, destination_long)
        distance=geopy.distance.geodesic(origin, destination).km
        try:
            if distance <= int(dh["fin_d"][0]):
                times = times + 1
                
        except:
            print(i,"error")
    dh.at[i,"fin_q"] = times

dh.to_csv("台北市房屋交易_最新版.csv", encoding = "utf-8", index=False)
