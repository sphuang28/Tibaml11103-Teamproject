# %% [markdown]
# <a href="https://colab.research.google.com/github/sphuang28/Tibaml11103-Teamproject/blob/main/%E6%9C%80%E7%B5%82%E7%89%88_%E8%A8%AD%E6%96%BD%E8%BD%89%E6%8F%9B(r2_0_77)Ver1_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import geopy.distance
from google.colab import files
import os
from google.colab import drive

drive.mount('/content/drive')
os.chdir('/content/drive/My Drive/Tibame_03期_第二組團專/訓練用資料/特徵檔案') #切換該目錄
os.listdir()

# 載入房屋交易csv檔

dh = pd.read_csv("台北市房屋交易_model_1130.csv", encoding = "utf-8")

#================= 1.公園 =============
def park():
  
  # 載入設施csv檔
  df = pd.read_excel("/content/drive/My Drive/Tibame_03期_第二組團專/訓練用資料/特徵檔案/設施座標表Ver2.xlsx", sheet_name="公園") 

  dh["固定範圍(公園)"]=1800/1000
  dh["公園數量"]=""
  for i in range(len(dh)):
      times = 0
      origin_lat = str(dh["緯度"][i])
      origin_long = str(dh["經度"][i])
      origin = (origin_lat, origin_long)
      for j in range(len(df)):
          destination_lat = str(df["lat"][j])
          destination_long = str(df["lng"][j])
          destination = (destination_lat, destination_long)
          distance=geopy.distance.geodesic(origin, destination).km
          try:
              if distance <= 1800/1000:
                  times = times + 1
                  
          except:
              print(i,"error")
      dh.at[i,"公園數量"] = times

#================= 2.博物館 =============
def mu():

  # 載入設施csv檔
  df = pd.read_excel("/content/drive/My Drive/Tibame_03期_第二組團專/訓練用資料/特徵檔案/設施座標表Ver2.xlsx", sheet_name="博物館")  

  dh["固定範圍(博物館)"]=2000/1000
  dh["博物館數量"]=""
  for i in range(len(dh)):
      times = 0
      origin_lat = str(dh["緯度"][i])
      origin_long = str(dh["經度"][i])
      origin = (origin_lat, origin_long)
      for j in range(len(df)):
          destination_lat = str(df["lat"][j])
          destination_long = str(df["lng"][j])
          destination = (destination_lat, destination_long)
          distance=geopy.distance.geodesic(origin, destination).km
          try:
              if distance <= 2000/1000:
                  times = times + 1
                  
          except:
              print(i,"error")
      dh.at[i,"博物館數量"] = times

#================= 3.圖書館 =============
def lib():

  # 載入設施csv檔
  df = pd.read_excel("/content/drive/My Drive/Tibame_03期_第二組團專/訓練用資料/特徵檔案/設施座標表Ver2.xlsx", sheet_name="圖書館")  

  dh["固定範圍(圖書館)"]=600/1000
  dh["圖書館數量"]=""
  for i in range(len(dh)):
      times = 0
      origin_lat = str(dh["緯度"][i])
      origin_long = str(dh["經度"][i])
      origin = (origin_lat, origin_long)
      for j in range(len(df)):
          destination_lat = str(df["lat"][j])
          destination_long = str(df["lng"][j])
          destination = (destination_lat, destination_long)
          distance=geopy.distance.geodesic(origin, destination).km
          try:
              if distance <= 600/1000:
                  times = times + 1
                  
          except:
              print(i,"error")
      dh.at[i,"圖書館數量"] = times

#================= 4.捷運出口數 =============
def mrt():
# 載入設施csv檔
  df = pd.read_excel("/content/drive/My Drive/Tibame_03期_第二組團專/訓練用資料/特徵檔案/設施座標表Ver2.xlsx", sheet_name="捷運出口")  

  dh["固定範圍(捷運出口)"]=400/1000
  dh["捷運出口數量"]=""
  for i in range(len(dh)):
      times = 0
      origin_lat = str(dh["緯度"][i])
      origin_long = str(dh["經度"][i])
      origin = (origin_lat, origin_long)
      for j in range(len(df)):
          destination_lat = str(df["lat"][j])
          destination_long = str(df["lng"][j])
          destination = (destination_lat, destination_long)
          distance=geopy.distance.geodesic(origin, destination).km
          try:
              if distance <= 400/1000:
                  times = times + 1
                  
          except:
              print(i,"error")
      dh.at[i,"捷運出口數量"] = times

#================= 5.學校 =============
def edu():
  # 載入設施csv檔
  df = pd.read_excel("/content/drive/My Drive/Tibame_03期_第二組團專/訓練用資料/特徵檔案/設施座標表Ver2.xlsx", sheet_name="學校") 

  dh["固定範圍(學校)"]=1800/1000
  dh["學校數量"]=""
  for i in range(len(dh)):
      times = 0
      origin_lat = str(dh["緯度"][i])
      origin_long = str(dh["經度"][i])
      origin = (origin_lat, origin_long)
      for j in range(len(df)):
          destination_lat = str(df["lat"][j])
          destination_long = str(df["lng"][j])
          destination = (destination_lat, destination_long)
          distance=geopy.distance.geodesic(origin, destination).km
          try:
              if distance <= 1800/1000:
                  times = times + 1
                  
          except:
              print(i,"error")
      dh.at[i,"學校數量"] = times

#================= 6.消防 =============
def fire():
  # 載入設施csv檔
  df = pd.read_excel("/content/drive/My Drive/Tibame_03期_第二組團專/訓練用資料/特徵檔案/設施座標表Ver2.xlsx", sheet_name="消防") 

  dh["固定範圍(消防局)"]=2000/1000
  dh["消防局數量"]=""
  for i in range(len(dh)):
      times = 0
      origin_lat = str(dh["緯度"][i])
      origin_long = str(dh["經度"][i])
      origin = (origin_lat, origin_long)
      for j in range(len(df)):
          destination_lat = str(df["lat"][j])
          destination_long = str(df["lng"][j])
          destination = (destination_lat, destination_long)
          distance=geopy.distance.geodesic(origin, destination).km
          try:
              if distance <= 2000/1000:
                  times = times + 1
                  
          except:
              print(i,"error")
      dh.at[i,"消防局數量"] = times

#================= 7.禮儀 =============
def dead():
  # 載入設施csv檔
  df = pd.read_excel("/content/drive/My Drive/Tibame_03期_第二組團專/訓練用資料/特徵檔案/設施座標表Ver2.xlsx", sheet_name="禮儀")  

  dh["固定範圍(禮儀)"]=1000/1000
  dh["禮儀數量"]=""
  for i in range(len(dh)):
      times = 0
      origin_lat = str(dh["緯度"][i])
      origin_long = str(dh["經度"][i])
      origin = (origin_lat, origin_long)
      for j in range(len(df)):
          destination_lat = str(df["lat"][j])
          destination_long = str(df["lng"][j])
          destination = (destination_lat, destination_long)
          distance=geopy.distance.geodesic(origin, destination).km
          try:
              if distance <= 1000/1000:
                  times = times + 1
                  
          except:
              print(i,"error")
      dh.at[i,"禮儀數量"] = times

#================= 8.警察 =============
def pol():
  # 載入設施csv檔
  df = pd.read_excel("/content/drive/My Drive/Tibame_03期_第二組團專/訓練用資料/特徵檔案/設施座標表Ver2.xlsx", sheet_name="警察")  

  dh["固定範圍(警察局)"]=1600/1000
  dh["警察局數量"]=""
  for i in range(len(dh)):
      times = 0
      origin_lat = str(dh["緯度"][i])
      origin_long = str(dh["經度"][i])
      origin = (origin_lat, origin_long)
      for j in range(len(df)):
          destination_lat = str(df["lat"][j])
          destination_long = str(df["lng"][j])
          destination = (destination_lat, destination_long)
          distance=geopy.distance.geodesic(origin, destination).km
          try:
              if distance <= 1600/1000:
                  times = times + 1
                  
          except:
              print(i,"error")
      dh.at[i,"警察局數量"] = times

#================= 9.郵局 =============
def post():
  # 載入設施csv檔
  df = pd.read_excel("/content/drive/My Drive/Tibame_03期_第二組團專/訓練用資料/特徵檔案/設施座標表Ver2.xlsx", sheet_name="郵局") 

  dh["固定範圍(郵局)"]=1200/1000
  dh["郵局數量"]=""
  for i in range(len(dh)):
      times = 0
      origin_lat = str(dh["緯度"][i])
      origin_long = str(dh["經度"][i])
      origin = (origin_lat, origin_long)
      for j in range(len(df)):
          destination_lat = str(df["lat"][j])
          destination_long = str(df["lng"][j])
          destination = (destination_lat, destination_long)
          distance=geopy.distance.geodesic(origin, destination).km
          try:
              if distance <= 1200/1000:
                  times = times + 1
                  
          except:
              print(i,"error")
      dh.at[i,"郵局數量"] = times

#================= 10.金融 =============
def fin():
  # 載入設施csv檔
  df = pd.read_excel("/content/drive/My Drive/Tibame_03期_第二組團專/訓練用資料/特徵檔案/設施座標表Ver2.xlsx", sheet_name="金融")  

  dh["固定範圍(金融)"]=1400/1000
  dh["金融數量"]=""
  for i in range(len(dh)):
      times = 0
      origin_lat = str(dh["緯度"][i])
      origin_long = str(dh["經度"][i])
      origin = (origin_lat, origin_long)
      for j in range(len(df)):
          destination_lat = str(df["lat"][j])
          destination_long = str(df["lng"][j])
          destination = (destination_lat, destination_long)
          distance=geopy.distance.geodesic(origin, destination).km
          try:
              if distance <= 1400/1000:
                  times = times + 1
                  
          except:
              print(i,"error")
      dh.at[i,"金融數量"] = times

#================= 11.醫療醫院 =============
def hosp():
  # 載入設施csv檔
  df = pd.read_excel("/content/drive/My Drive/Tibame_03期_第二組團專/訓練用資料/特徵檔案/設施座標表Ver2.xlsx", sheet_name="醫療醫院")  

  dh["固定範圍(醫院)"]=200/1000
  dh["醫院數量"]=""
  for i in range(len(dh)):
      times = 0
      origin_lat = str(dh["緯度"][i])
      origin_long = str(dh["經度"][i])
      origin = (origin_lat, origin_long)
      for j in range(len(df)):
          destination_lat = str(df["lat"][j])
          destination_long = str(df["lng"][j])
          destination = (destination_lat, destination_long)
          distance=geopy.distance.geodesic(origin, destination).km
          try:
              if distance <= 200/1000:
                  times = times + 1
                  
          except:
              print(i,"error")
      dh.at[i,"醫院數量"] = times

#================= 12.醫療診所 =============
def clinic():
  # 載入設施csv檔
  df = pd.read_excel("/content/drive/My Drive/Tibame_03期_第二組團專/訓練用資料/特徵檔案/設施座標表Ver2.xlsx", sheet_name="醫療診所")  

  dh["固定範圍(診所)"]=1600/1000
  dh["診所數量"]=""
  for i in range(len(dh)):
      times = 0
      origin_lat = str(dh["緯度"][i])
      origin_long = str(dh["經度"][i])
      origin = (origin_lat, origin_long)
      for j in range(len(df)):
          destination_lat = str(df["lat"][j])
          destination_long = str(df["lng"][j])
          destination = (destination_lat, destination_long)
          distance=geopy.distance.geodesic(origin, destination).km
          try:
              if distance <= 1600/1000:
                  times = times + 1
                  
          except:
              print(i,"error")
      dh.at[i,"診所數量"] = times

#================= 13.醫療藥局 =============
def pharmacy():
  # 載入設施csv檔
  df = pd.read_excel("/content/drive/My Drive/Tibame_03期_第二組團專/訓練用資料/特徵檔案/設施座標表Ver2.xlsx", sheet_name="醫療藥局")  

  dh["固定範圍(藥局)"]=400/1000
  dh["藥局數量"]=""
  for i in range(len(dh)):
      times = 0
      origin_lat = str(dh["緯度"][i])
      origin_long = str(dh["經度"][i])
      origin = (origin_lat, origin_long)
      for j in range(len(df)):
          destination_lat = str(df["lat"][j])
          destination_long = str(df["lng"][j])
          destination = (destination_lat, destination_long)
          distance=geopy.distance.geodesic(origin, destination).km
          try:
              if distance <= 400/1000:
                  times = times + 1
                  
          except:
              print(i,"error")
      dh.at[i,"藥局數量"] = times

#主程式

park()   
mu() 
lib() 
mrt() 
edu() 
fire() 
dead() 
pol() 
post()
fin()  
hosp()  
clinic()
pharmacy()

dh.to_csv("台北市房屋交易_model_1130_加設施.csv", encoding = "utf-8", index=False)
